# %%
# http://vis-www.cs.umass.edu/lfw/
# i dowloaded a dataset of iamges

# %%
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
# uncompress tar GZ labelled faces in the wild dataset
# !tar -xf lfw.tgz

# %%
# move LFW Images to the following repository data/negative 
for dir in os.listdir('lfw'):
    for file in os.listdir(os.path.join('lfw',dir)):
        ex_path = os.path.join('lfw',dir,file)
        new_path = os.path.join('data','negative',file)
        os.replace(ex_path,new_path)

# %% [markdown]
# # Collect Positive and Anchor Classes

# %%
import uuid
#a library to geenrate unique images names

# %%
uuid.uuid1()
# Out:
# UUID('62a89fc2-3b62-11ed-8eeb-b4a9fc5fc791')

# %%
cap = cv2.VideoCapture(0)
while (cap.isOpened()):
    ret , frame = cap.read()
    
    frame = frame[150:480,230:520,:]
    
    
    if cv2.waitKey(1) & 0xFF == ord('a'):
        name = os.path.join('data','anchor','{}.jpg'.format(uuid.uuid1()) )
        cv2.imwrite(name,frame)
        
        
    if cv2.waitKey(1) & 0xFF == ord('p'):
        name = os.path.join('data','positive','{}.jpg'.format(uuid.uuid1()))
        cv2.imwrite(name,frame)
    
    
    cv2.imshow('image',frame)
                            
                            
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
                            
                            
#release the webcam
cap.release()
# close the image show frame
cv2.destroyAllWindows()

# %%
plt.imshow(frame)

# %%
plt.imshow(frame[150:480,230:520,:])
